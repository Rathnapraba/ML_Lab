# %%
print("\U0001f600")
# Out:
# 😀

# %%
print("\U0001f606")
# Out:
# 😆

# %%
print("\U0001f923")
# Out:
# 🤣

# %%
print("\N{grinning face}")
print("\N{slightly smiling face}")
print("\N{winking face}")
# Out:
# 😀
# 🙂
# 😉

# %%
pip install emoji --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting emoji
#   Downloading emoji-2.1.0.tar.gz (216 kB)
#      |████████████████████████████████| 216 kB 3.2 MB/s
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-2.1.0-py3-none-any.whl size=212392 sha256=57f2698ad524f67953c82e095635995c10304af8d47788b641cf53337671377b
#   Stored in directory: /root/.cache/pip/wheels/77/75/99/51c2a119f4cfd3af7b49cc57e4f737bed7e40b348a85d82804
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-2.1.0

# %%
import emoji
print(emoji.emojize('Hi there! :heart_decoration:'))
# Out:
# Hi there! 💟

# %%
print(emoji.emojize(":grinning_face_with_big_eyes:"))
print(emoji.emojize(":smiling_cat_with_heart-eyes:"))
print(emoji.emojize(":zipper-mouth_face:"))
# Out:
# 😃
# 😻
# 🤐

# %%
# !pip install -q transformers
# Out:
#      |████████████████████████████████| 4.9 MB 2.6 MB/s
#      |████████████████████████████████| 6.6 MB 40.9 MB/s
#      |████████████████████████████████| 120 kB 57.4 MB/s

# %%
from transformers import pipeline
sentiment_pipeline = pipeline("sentiment-analysis")
data = ["I LOVE NOBODY","TODAY IS A BORING DAY"]
sentiment_pipeline(data)
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# [{'label': 'NEGATIVE', 'score': 0.9963550567626953},
#  {'label': 'NEGATIVE', 'score': 0.9994691014289856}]

# %%
specific_model = pipeline(model='finiteautomata/bertweet-base-sentiment-analysis')
specific_model(data)
# Out:
# Downloading:   0%|          | 0.00/890 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.16k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/540M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/295 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/843k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/17.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]
# [{'label': 'POS', 'score': 0.9905869364738464},
#  {'label': 'NEG', 'score': 0.9813030362129211}]

# %%
from textblob import TextBlob
testimonial = TextBlob("I am hungry")
print(testimonial.sentiment)
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)
